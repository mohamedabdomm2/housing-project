# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt

# %% [markdown]
# ## Data Preperation

# %%
df1= pd.read_csv("aqarmap_data/aqarmap_data1.csv")
df2= pd.read_csv("aqarmap_data/aqarmap_data2.csv")
df3= pd.read_csv("aqarmap_data/aqarmap_data3.csv")

# %%
print(df1.info())
df1.head(3)
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1497 entries, 0 to 1496
# Data columns (total 10 columns):
#  #   Column     Non-Null Count  Dtype
# ---  ------     --------------  -----
#  0   URL        1497 non-null   object
#  1   Price      1497 non-null   object
#  2   Address    1497 non-null   object
#  3   Rooms      1461 non-null   float64
#  4   Baths      1461 non-null   float64
#  5   Area       1497 non-null   int64
#  6   Lat        1484 non-null   float64
#  7   Lon        1484 non-null   float64
#  8   Floor      1444 non-null   object
#  9   Finishing  1445 non-null   object
# dtypes: float64(4), int64(1), object(5)
# memory usage: 117.1+ KB
# None
#                                                  URL                 Price  \
# 0  https://aqarmap.com.eg/ar/listing/5923848-for-...   7,900,000\n    جنيه
# 1  https://aqarmap.com.eg/ar/listing/6511345-for-...   1,550,000\n    جنيه
# 2  https://aqarmap.com.eg/ar/listing/6108263-for-...  13,000,000\n    جنيه
#
#                                              Address  Rooms  Baths  Area  \
# 0  القاهرة الكبرى  /  كمبوند تراس - بنك الاسكان و...    3.0    3.0   176
# 1                         القاهرة الكبرى  /  منطقة أ    2.0    2.0    95
# 2                     القاهرة الكبرى  /  طريق مدينتي    4.0    4.0   245
#
#          Lat        Lon Floor  Finishing
# 0  30.015287  30.983945     4  نصف تشطيب
# 1  29.986745  31.099302   NaN        NaN
# 2  30.100866  31.632139     1  سوبر لوكس

# %%
print(df2.info())
df2.head(3)
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1804 entries, 0 to 1803
# Data columns (total 10 columns):
#  #   Column     Non-Null Count  Dtype
# ---  ------     --------------  -----
#  0   URL        1804 non-null   object
#  1   Price      1804 non-null   object
#  2   Address    1359 non-null   object
#  3   Rooms      1648 non-null   float64
#  4   Baths      1648 non-null   float64
#  5   Area       1729 non-null   float64
#  6   Lat        1729 non-null   float64
#  7   Lon        1729 non-null   float64
#  8   Floor      1588 non-null   object
#  9   Finishing  1589 non-null   object
# dtypes: float64(5), object(5)
# memory usage: 141.1+ KB
# None
#                                                  URL           Price  \
# 0  https://aqarmap.com.eg/ar/listing/6495695-for-...  5,000,000 جنيه
# 1  https://aqarmap.com.eg/ar/listing/6620952-for-...  5,200,000 جنيه
# 2  https://aqarmap.com.eg/ar/listing/6625833-for-...  9,000,000 جنيه
#
#                        Address  Rooms  Baths   Area        Lat        Lon  \
# 0  القاهرة الكبرى / شارع تاجان    4.0    3.0  500.0  30.062840  31.467344
# 1                          NaN    3.0    3.0  154.0  30.091361  31.379453
# 2    القاهرة الكبرى / شارع 256    4.0    3.0  250.0  29.967712  31.269590
#
#   Floor         Finishing
# 0     1         نصف تشطيب
# 1     2  اكسترا سوبر لوكس
# 2    10  اكسترا سوبر لوكس

# %%
print(df3.info())
df3.head(3)
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 8553 entries, 0 to 8552
# Data columns (total 10 columns):
#  #   Column     Non-Null Count  Dtype
# ---  ------     --------------  -----
#  0   URL        8553 non-null   object
#  1   Price      8553 non-null   object
#  2   Address    8553 non-null   object
#  3   Area       8553 non-null   float64
#  4   Rooms      7933 non-null   float64
#  5   Baths      7248 non-null   float64
#  6   Lat        8083 non-null   float64
#  7   Lon        8083 non-null   float64
#  8   Floor      7125 non-null   object
#  9   Finishing  7125 non-null   object
# dtypes: float64(5), object(5)
# memory usage: 668.3+ KB
# None
#                                                  URL           Price  \
# 0  https://aqarmap.com.eg/ar/listing/6586177-for-...  5,000,000 جنيه
# 1  https://aqarmap.com.eg/ar/listing/6588316-for-...  3,640,000 جنيه
# 2  https://aqarmap.com.eg/ar/listing/6588088-for-...  1,265,000 جنيه
#
#                                      Address   Area  Rooms  Baths        Lat  \
# 0  الاسكندرية  /  شارع أبو قير - طريق الحرية  140.0    1.0    2.0  31.245682
# 1              القاهرة الكبرى  /  الحي الأول  260.0    3.0    3.0  30.083355
# 2         القاهرة الكبرى  /  شارع الملك فيصل  150.0    3.0    3.0  30.016787
#
#          Lon Floor   Finishing
# 0  29.954224     4   سوبر لوكس
# 1  31.552734     2   نصف تشطيب
# 2  31.184692     3  بدون تشطيب

# %%
def Outliers(data,rows,cols):    

    fig, axes = plt.subplots(rows, cols, figsize=(12, 8))
    axes = axes.flatten()

    for i, col in enumerate(data):
        df[col].plot(kind="box", ax=axes[i])
        axes[i].set_title(f"Boxplot of {col}")

    plt.tight_layout()
    plt.show()

# %% [markdown]
# ## Data wrangling

# %%
def wrangle(file):
    # reading the csv file
    df = pd.read_csv(file)
    
    # converting Price and floor columns to float
    df["Price"] = (
    df["Price"].str
    .replace("/n    ","").str
    .replace("جنيه","").str
    .replace(",","")
    .astype(float)
    )
    df["Floor"] = df["Floor"].str.replace("الارضي","0").astype(float)

    # splitting the address to Governate and Neighbourhood
    df["Governate"] = df["Address"].str.split("/",expand=True)[0]
    df["Neighbourhood"] = df["Address"].str.split("/",expand=True)[1].str.split("-",expand=True)[0]
    df.drop("Address",axis=1,inplace=True)

    # Cleaning up and standardizing Governate names
    df["Governate"] = df["Governate"].str.strip()  # Remove leading and trailing spaces
    df["Governate"] = df["Governate"].replace({
        'الاسكندريه': 'الاسكندرية',
        'االقاهرة': 'القاهرة الكبرى',
        'الإسكندرية': 'الاسكندرية',
        'االقاهرة الكبرى': 'الجيزة',
    
    })

    # removing outliars
    mask_rooms = df["Rooms"] < 10
    mask_baths = df["Baths"] < 10
    mask_area = df["Area"] < 500
    mask_price = df["Price"] < 20_000_000
    mask_floor = df["Floor"] < 40
    df = df[mask_rooms & mask_baths & mask_area & mask_price & mask_floor]

    #filling missing values with mode for each column
    df["Floor"] = df["Floor"].fillna(df["Floor"].mode()[0])
    df["Finishing"] = df["Finishing"].fillna(df["Finishing"].mode()[0])
    df["Governate"] = df["Governate"].fillna(df["Governate"].mode()[0])
    df["Neighbourhood"] = df["Neighbourhood"].fillna(df["Neighbourhood"].mode()[0])

    # dropping any remaining missing values
    df.dropna(inplace=True)

    # droping duplicates
    df.drop_duplicates(inplace=True)

    # casting float columns to int dtype
    df["Floor"] = df["Floor"].astype(int)
    df["Rooms"] = df["Rooms"].astype(int)
    df["Baths"] = df["Baths"].astype(int)
    df["Area"] = df["Area"].astype(int)
    df["Price"] = df["Price"].astype(int)

    return df

# %%
df1 = wrangle("aqarmap_data/aqarmap_data1.csv")
df2 = wrangle("aqarmap_data/aqarmap_data2.csv")
df3 = wrangle("aqarmap_data/aqarmap_data3.csv")

# %%
df = pd.concat([df1, df2, df3], ignore_index=True)
df.head()
# Out:
#                                                  URL     Price  Rooms  Baths  \
# 0  https://aqarmap.com.eg/ar/listing/5923848-for-...   7900000      3      3
# 1  https://aqarmap.com.eg/ar/listing/6108263-for-...  13000000      4      4
# 2  https://aqarmap.com.eg/ar/listing/6418731-for-...   7500000      3      2
# 3  https://aqarmap.com.eg/ar/listing/6501759-for-...   8400000      4      3
# 4  https://aqarmap.com.eg/ar/listing/6320579-for-...   3200000      2      1
#
#    Area        Lat        Lon  Floor         Finishing       Governate  \
# 0   176  30.015287  30.983945      4         نصف تشطيب  القاهرة الكبرى
# 1   245  30.100866  31.632139      1         سوبر لوكس  القاهرة الكبرى
# 2   180  30.024799  31.516782      1         سوبر لوكس  القاهرة الكبرى
# 3   230  30.034311  31.461851      1  اكسترا سوبر لوكس  القاهرة الكبرى
# 4   116  29.986745  31.319028      1         سوبر لوكس  القاهرة الكبرى
#
#            Neighbourhood
# 0           كمبوند تراس
# 1            طريق مدينتي
# 2         اللوتس الجديدة
# 3           شارع الجابري
# 4    كمبوند أشجار دارنا

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 7512 entries, 0 to 7511
# Data columns (total 11 columns):
#  #   Column         Non-Null Count  Dtype
# ---  ------         --------------  -----
#  0   URL            7512 non-null   object
#  1   Price          7512 non-null   int32
#  2   Rooms          7512 non-null   int32
#  3   Baths          7512 non-null   int32
#  4   Area           7512 non-null   int32
#  5   Lat            7512 non-null   float64
#  6   Lon            7512 non-null   float64
#  7   Floor          7512 non-null   int32
#  8   Finishing      7512 non-null   object
#  9   Governate      7512 non-null   object
#  10  Neighbourhood  7512 non-null   object
# dtypes: float64(2), int32(5), object(4)
# memory usage: 499.0+ KB

# %%
df.duplicated().sum()
# Out:
# 0

# %%
# the percentage of null values in each column 
(df.isna().sum() / len(df)).round(2)
# Out:
# URL              0.0
# Price            0.0
# Rooms            0.0
# Baths            0.0
# Area             0.0
# Lat              0.0
# Lon              0.0
# Floor            0.0
# Finishing        0.0
# Governate        0.0
# Neighbourhood    0.0
# dtype: float64

# %%
numeric_data = df.select_dtypes("number")
numeric_data.describe()
# Out:
#               Price        Rooms        Baths         Area          Lat  \
# count  7.512000e+03  7512.000000  7512.000000  7512.000000  7512.000000
# mean   6.447174e+06     2.454073     2.024095   143.876731    29.455520
# std    3.613134e+06     0.913526     0.893522    64.381954     1.246107
# min    4.000000e+05     1.000000     1.000000     5.000000    27.042949
# 25%    3.636750e+06     2.000000     1.000000    98.000000    29.921613
# 50%    5.600000e+06     3.000000     2.000000   140.000000    30.015287
# 75%    8.400000e+06     3.000000     3.000000   176.000000    30.064340
# max    1.995000e+07     7.000000     7.000000   480.000000    31.508313
#
#                Lon        Floor
# count  7512.000000  7512.000000
# mean     31.792878     2.581603
# std       1.197839     2.545707
# min      27.243101     0.000000
# 25%      31.019897     1.000000
# 50%      31.481323     2.000000
# 75%      31.720029     3.000000
# max      34.417173    32.000000

# %%
fig, axes = plt.subplots(3, 3, figsize=(12, 8))

axes = axes.flatten()

for i, col in enumerate(numeric_data[:6]):
    df[col].plot(kind="box", ax=axes[i])
    axes[i].set_title(f"Boxplot of {col}")

plt.tight_layout()
plt.show()

# %%
df["Area"].value_counts().sort_index().tail(10)
# Out:
# Area
# 400    22
# 420     9
# 425     2
# 430     2
# 440     3
# 444     1
# 450     9
# 460     1
# 470     2
# 480     4
# Name: count, dtype: int64

# %%
df["Price"].value_counts().sort_index().tail(10)
# Out:
# Price
# 19065000    1
# 19200000    2
# 19305000    1
# 19305903    1
# 19366000    1
# 19390000    1
# 19500000    1
# 19750000    1
# 19865000    1
# 19950000    1
# Name: count, dtype: int64

# %%
df["Floor"].value_counts().sort_index().tail(10)
# Out:
# Floor
# 11     39
# 12     38
# 13    116
# 14      4
# 15      2
# 16      4
# 17      2
# 18      5
# 22      1
# 32      1
# Name: count, dtype: int64

# %%
# Exploring categorical columns
categorical_data = df.select_dtypes("object")
categorical_data.nunique()
# Out:
# URL              7496
# Finishing           5
# Governate          17
# Neighbourhood    1381
# dtype: int64

# %%
df["Finishing"].value_counts()
# Out:
# Finishing
# سوبر لوكس           2843
# نصف تشطيب           1985
# اكسترا سوبر لوكس    1749
# بدون تشطيب           772
# لوكس                 163
# Name: count, dtype: int64

# %%
df["Governate"].value_counts()
# Out:
# Governate
# القاهرة الكبرى                5391
# البحر الأحمر                  1686
# الاسكندرية                     282
# الساحل الشمالي                  97
# دمياط                           11
# السويس                          11
# الجيزة                           9
# الدقهلية                         8
# العين السخنة                     5
# مرسى مطروح                       4
# الاسماعيلية                      2
# الشرقية                          1
# المنوفية                         1
# بور سعيد                         1
# المنيا                           1
# القليوبية                        1
# التوسعات السياحية الشمالية       1
# Name: count, dtype: int64

# %%
df["Neighbourhood"].value_counts()
# Out:
# Neighbourhood
#  حي الكوثر                     488
# حي الكوثر                      283
#  الاحياء                       229
#  مروج                          150
#  مبارك 6                       130
#                               ...
#  شارع متحف المنيل                1
#  منتجع كمران                     1
#  ذا تاور                         1
#  كمبوند الباتيو ريفا             1
#  المنطقه الخامسه عشر عمارات      1
# Name: count, Length: 1381, dtype: int64

# %%
# saving the cleaned data
df.to_csv("aqarmap_data/cleaned_housing_data.csv", index=False)
