# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns

# %%
data = pd.read_csv("aqarmap_data/cleaned_housing_data.csv")
data.head()
# Out:
#                                                  URL     Price  Rooms  Baths  \
# 0  https://aqarmap.com.eg/ar/listing/5923848-for-...   7900000      3      3
# 1  https://aqarmap.com.eg/ar/listing/6108263-for-...  13000000      4      4
# 2  https://aqarmap.com.eg/ar/listing/6418731-for-...   7500000      3      2
# 3  https://aqarmap.com.eg/ar/listing/6501759-for-...   8400000      4      3
# 4  https://aqarmap.com.eg/ar/listing/6320579-for-...   3200000      2      1
#
#    Area        Lat        Lon  Floor         Finishing Governate  \
# 0   176  30.015287  30.983945      4         نصف تشطيب   القاهره
# 1   245  30.100866  31.632139      1         سوبر لوكس   القاهره
# 2   180  30.024799  31.516782      1         سوبر لوكس   القاهره
# 3   230  30.034311  31.461851      1  اكسترا سوبر لوكس   القاهره
# 4   116  29.986745  31.319028      1         سوبر لوكس   القاهره
#
#            Neighbourhood
# 0           كمبوند تراس
# 1            طريق مدينتي
# 2         اللوتس الجديدة
# 3           شارع الجابري
# 4    كمبوند أشجار دارنا

# %% [markdown]
# ### Exploring the numaric features

# %%
numeric_data = data.select_dtypes(include=[np.number])

# %%
plt.scatter(data=data,x="Area",y="Price")
plt.xlabel("Area m2")
plt.ylabel("Price")
plt.title("Area vs Price");

# %%
corr = numeric_data.corr()
mask = np.tril(np.ones_like(corr, dtype=bool))
sns.heatmap(corr, mask=mask, cmap="Blues_r", annot=True, square=True);
